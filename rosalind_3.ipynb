# %%
seq1 ='...'
seq2 = '...'

count = 0 
for i in range(0, len(seq1)):  #looks for each letter in each sequence and counts if it is mismatch
    if seq1[i] != seq2[i]:
        count += 1;
        
print ('there are',count, 'point mutations')
# Out:
# there are 478 point mutations
