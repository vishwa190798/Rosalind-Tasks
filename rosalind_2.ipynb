# %%
dna = '...'

#to store complementary sequence
comp=''
for i in dna:
    if i == 'A':
        comp = comp + 'T'
    elif i == 'T':
        comp = comp + 'A'
    elif i == 'G':
        comp = comp + 'C'
    elif i == 'C':
        comp = comp + 'G'
        
#to print the reverse sequence
print(comp[::-1])
# Out:
# ...
